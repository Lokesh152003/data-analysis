# %%
import pandas as pd

# %%
mydf=pd.read_csv("/content/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
mydf
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
LR=LinearRegression()
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC=DecisionTreeClassifier()

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
column=['DistanceFromHome','TotalWorkingYears','YearsAtCompany']

# %%
Target=mydf['Attrition']

# %%
features=mydf[column]

# %%
DTC.fit(features,Target)
# Out:
# DecisionTreeClassifier()

# %%
DTC.predict([[2,7,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
a=int(input("Enter Distance From Home :"))
b=int(input("Enter Total Working Years :"))
c=int(input("Enter Years At Company :"))
p=DTC.predict([[a,b,c]])
if p=='Yes':
  print("Attrition happens")
else:0
  print("Attrition doesnot happens")
# Out:
# Enter Distance From Home :2
# Enter Total Working Years :7
# Enter Years At Company :0
# Attrition happens
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz,plot_tree

# %%
plot_tree(DTC)
# Out:
# [Text(0.3295785744273166, 0.9761904761904762, 'x[1] <= 1.5\ngini = 0.27\nsamples = 1470\nvalue = [1233, 237]'),
#  Text(0.038580778504994834, 0.9285714285714286, 'x[0] <= 17.5\ngini = 0.5\nsamples = 92\nvalue = [47, 45]'),
#  Text(0.03169135377196004, 0.8809523809523809, 'x[0] <= 12.5\ngini = 0.483\nsamples = 76\nvalue = [45, 31]'),
#  Text(0.026179813985532208, 0.8333333333333334, 'x[0] <= 10.5\ngini = 0.491\nsamples = 69\nvalue = [39, 30]'),
#  Text(0.02342404409231829, 0.7857142857142857, 'x[2] <= 0.5\ngini = 0.48\nsamples = 65\nvalue = [39, 26]'),
#  Text(0.011023079572855667, 0.7380952380952381, 'x[1] <= 0.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.00826730967964175, 0.6904761904761905, 'x[0] <= 2.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.005511539786427834, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.011023079572855667, 0.6428571428571429, 'x[0] <= 9.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
ran=RandomForestClassifier(n_estimators=10)

# %%
ran.fit(features,Target)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
ran.predict([[2,7,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %%
a=int(input("Enter Distance From Home :"))
b=int(input("Enter Total Working Years :"))
c=int(input("Enter Years At Company :"))
p=ran.predict([[a,b,c]])
if p=='Yes':
  print("Attrition happens")
else:
  print("Attrition doesnot happens")
# Out:
# Enter Distance From Home :2
# Enter Total Working Years :7
# Enter Years At Company :0
# Attrition happens
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir="tree_visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
for i , tree in enumerate(ran.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file=os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file , feature_names=["Literacy", "Cleanliness", "Crime_Rate"],
                class_names=[str(cls) for cls in ran.classes_], filled=True, rounded=True)

# %%
command=f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"tree {i} visualization saved to {tree_png_file}")
# Out:
# tree 9 visualization saved to tree_visualizations/tree_9.png
