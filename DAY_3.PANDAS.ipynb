# %%
import pandas as pd

# %% [markdown]
# PANDAS:

# %%
A=['lokesh','ram','dhanush']
b=[3,45,67]
r=pd.Series(A,b)
print(r)
# Out:
# 3      lokesh
# 45        ram
# 67    dhanush
# dtype: object

# %%
dia=pd.read_csv("/diabetcsv.csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
demodt=pd.read_csv("/demodt.txt")
demodt
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diabetes=pd.read_excel("/diabetes.xlsx")
diabetes
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diabetes=pd.read_excel("/diabetes.xlsx",sheet_name="dora")
diabetes
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
diabetes.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
df=pd.read_csv("/grades.txt")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (16, 1)
# 16
# 1

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
gc=pd.read_csv("/grades_withnulls.csv")
gc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
gc.isnull()#isnull() gives null values then True
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
gc.isnull().sum() #gives column wise no of null values
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
gc.dropna() # removes the NaN values # it does not reflect the changes when you use only gc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
gc
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K   9.80  10.0   9.90    A+       1
# 1   Rajesh        M   8.90   9.1   9.30     A       1
# 2   Kissan        V   9.90   9.8  10.00     A       0
# 3     Mary        N   7.70   8.0  99.99     B       0
# 4     Jeen        K   9.80   9.1   9.90    A+       1
# 5      Raj        M   8.90   9.1   9.30     A       1
# 6   Hassan        V   9.90   9.0   9.20     A       1
# 7     Mari        N   7.70   8.0   7.10     B       1
# 8     Jess        K  99.99   9.1   9.90    A+       1
# 9   Rajini        M  99.99   9.1   9.30     A       0
# 10   Kiran        V  99.99   9.3   9.20     A       0
# 11    Maya        N   7.70   8.0   7.10     B       0
# 12   Jolin        K   9.80   9.1   9.90    A+       1
# 13  Rajesh        M   8.90   9.1   9.30     A       1
# 14    Riya        M   9.30   9.9  10.00     A       1
# 15    Sana        V   9.90   9.3   9.20     A       0
# ...

# %%
gc.dropna()#does not reflect the changes
gc.dropna(inplace=True)#reflect the changes
print(gc)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# gc --> null
#
# REMOVE:
#
#
#   1) inplace=True (give perminent delete of that row
#
#   2)dropna()(if does not reflect the changes)
#
#
#
# insert:
#
#  1)fillna()(it does not reflect hte changes)
#  2)inplace=true(it reflect the changes)

# %%
gc
gc.fillna(99.9)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0  99.9     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K  99.9   9.1   9.9    A+       1
# 9   Rajini        M  99.9   9.1   9.3     A       0
# 10   Kiran        V  99.9   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
gc.fillna(9.99,inplace=True)
gc
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K   9.80  10.0   9.90    A+       1
# 1   Rajesh        M   8.90   9.1   9.30     A       1
# 2   Kissan        V   9.90   9.8  10.00     A       0
# 3     Mary        N   7.70   8.0  99.99     B       0
# 4     Jeen        K   9.80   9.1   9.90    A+       1
# 5      Raj        M   8.90   9.1   9.30     A       1
# 6   Hassan        V   9.90   9.0   9.20     A       1
# 7     Mari        N   7.70   8.0   7.10     B       1
# 8     Jess        K  99.99   9.1   9.90    A+       1
# 9   Rajini        M  99.99   9.1   9.30     A       0
# 10   Kiran        V  99.99   9.3   9.20     A       0
# 11    Maya        N   7.70   8.0   7.10     B       0
# 12   Jolin        K   9.80   9.1   9.90    A+       1
# 13  Rajesh        M   8.90   9.1   9.30     A       1
# 14    Riya        M   9.30   9.9  10.00     A       1
# 15    Sana        V   9.90   9.3   9.20     A       0
# ...

# %%
gc1=pd.read_csv("/content/grades_withnulls.csv")
mv=gc1["SEM1"].mean()
print(mv)
gc1.fillna(mv,inplace=True)
gc1
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#access the data
#iloc=integer location,index
#loc=field names,index
gc1.loc[0]#first records(row)
#field(column)
#dataframe.loc[index] ->rows
#dataframe.loc[start:stop] ->range of rows
#data
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
gc1.loc[:5]#access 5 records(using range)
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# 2  Kissan        V   9.9   9.8  10.000000     A       0
# 3    Mary        N   7.7   8.0   8.992857     B       0
# 4    Jeen        K   9.8   9.1   9.900000    A+       1
# 5     Raj        M   8.9   9.1   9.300000     A       1

# %%
gc1.loc[10:13,("Names","Initials","SEM1")] #access first record and names and sem1 fields
# Out:
#      Names Initials      SEM1
# 10   Kiran        V  8.992857
# 11    Maya        N  7.700000
# 12   Jolin        K  9.800000
# 13  Rajesh        M  8.900000

# %%
gc1.iloc[10:13,0:3]
# Out:
#     Names Initials      SEM1
# 10  Kiran        V  8.992857
# 11   Maya        N  7.700000
# 12  Jolin        K  9.800000

# %%
gc1[gc1.SEM2==9.1]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 4     Jeen        K  9.800000   9.1   9.9    A+       1
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 8     Jess        K  8.992857   9.1   9.9    A+       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 13  Rajesh        M  8.900000   9.1   9.3     A       1

# %%
'''print the records who scored9.3 in sem3 '''
gc1[gc1.SEM3==9.3]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 13  Rajesh        M  8.900000   9.1   9.3     A       1

# %%
gc1.loc[gc1.SEM1 >9.0 , "Names"]
# Out:
# 0        Joe
# 2     Kissan
# 4       Jeen
# 6     Hassan
# 12     Jolin
# 14      Riya
# 15      Sana
# Name: Names, dtype: object

# %%
'''print the score of the students who scores more than 9 in sem3'''
gc1.loc[gc1.SEM3 >9.7 ,"Grade"]
#accessing the records with sem3>9.7 bujt printing only grade column
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
gc1.drop_duplicates() #remove duplicates and changes are not reflected
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
gc1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c676994873b7> in <cell line: 1>()
# ----> 1 gc1
#
# NameError: name 'gc1' is not defined

# %%
gc1.drop_duplicates(inplace=True)
gc1
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
gc1.head() #gives top 5 records
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# 2  Kissan        V   9.9   9.8  10.000000     A       0
# 3    Mary        N   7.7   8.0   8.992857     B       0
# 4    Jeen        K   9.8   9.1   9.900000    A+       1

# %%
gc1.tail() #gives last 5 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 11   Maya        N   7.7   8.0   7.1     B       0
# 12  Jolin        K   9.8   9.1   9.9    A+       1
# 14   Riya        M   9.3   9.9  10.0     A       1
# 15   Sana        V   9.9   9.3   9.2     A       0
# 16   Mark        N   7.7   8.0   7.0     B       0

# %%
#accessing records
print(gc1[gc1.index==1])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
print(gc1.loc[gc1.index==1,"Names"])
# Out:
# 1    Rajesh
# Name: Names, dtype: object

# %%
#columns
gc1.columns #views column names
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
l=list(gc1.columns)
print(l)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
gc1.rename(columns={'Grade':'GPA'},inplace=True)
gc1.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed'], dtype='object')

# %%
#creating a new column
#dfname['nem col']=values
gc1['conduct'] ='Good'
gc1
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed conduct
# 0      Joe        K  9.800000  10.0   9.900000    A+       1    Good
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1    Good
# 2   Kissan        V  9.900000   9.8  10.000000     A       0    Good
# 3     Mary        N  7.700000   8.0   8.992857     B       0    Good
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1    Good
# 5      Raj        M  8.900000   9.1   9.300000     A       1    Good
# 6   Hassan        V  9.900000   9.0   9.200000     A       1    Good
# 7     Mari        N  7.700000   8.0   7.100000     B       1    Good
# 8     Jess        K  8.992857   9.1   9.900000    A+       1    Good
# 9   Rajini        M  8.992857   9.1   9.300000     A       0    Good
# 10   Kiran        V  8.992857   9.3   9.200000     A       0    Good
# 11    Maya        N  7.700000   8.0   7.100000     B       0    Good
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1    Good
# ...

# %%
'''create a new column avg with avg values SEM1 ,SEM2,SEM3'''

gc1['AVG']=(gc1.SEM1+gc1.SEM2+gc1.SEM3)/3
gc1
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed conduct       AVG
# 0      Joe        K  9.800000  10.0   9.900000    A+       1    Good  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000     A       0    Good  9.900000
# 3     Mary        N  7.700000   8.0   8.992857     B       0    Good  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1    Good  9.600000
# 5      Raj        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000     A       1    Good  9.366667
# 7     Mari        N  7.700000   8.0   7.100000     B       1    Good  7.600000
# 8     Jess        K  8.992857   9.1   9.900000    A+       1    Good  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000     A       0    Good  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000     A       0    Good  9.164286
# ...

# %%
g=pd.read_csv("/content/grades.txt",sep=" ")
print(g)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B

# %%
gc1
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed conduct
# 0      Joe        K  9.800000  10.0   9.900000    A+       1    Good
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1    Good
# 2   Kissan        V  9.900000   9.8  10.000000     A       0    Good
# 3     Mary        N  7.700000   8.0   8.992857     B       0    Good
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1    Good
# 5      Raj        M  8.900000   9.1   9.300000     A       1    Good
# 6   Hassan        V  9.900000   9.0   9.200000     A       1    Good
# 7     Mari        N  7.700000   8.0   7.100000     B       1    Good
# 8     Jess        K  8.992857   9.1   9.900000    A+       1    Good
# 9   Rajini        M  8.992857   9.1   9.300000     A       0    Good
# 10   Kiran        V  8.992857   9.3   9.200000     A       0    Good
# 11    Maya        N  7.700000   8.0   7.100000     B       0    Good
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1    Good
# ...

# %% [markdown]
# pandas is viewing

# %%
gc1['SEM1'].plot.line()#dfname['col'].plot.line()
# Out:
# <Axes: >

# %%
gc1[['SEM1','SEM2']].plot.line()#dfname['col1','col2'].plot.line()
# Out:
# <Axes: >

# %%
gc1[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
gc1.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
gc1.plot(kind="scatter",x='SEM1',y='Names')
# Out:
# <Axes: xlabel='SEM1', ylabel='Names'>

# %%
gc1.plot(kind="hist",x='Names',y='AVG') #y - axis only takes numeric x- axis only counts
# Out:
# <Axes: ylabel='Frequency'>

# %%
gc1.plot.line()
# Out:
# <Axes: >

# %%
gc1.to_csv("mydf.csv") #filename.to_csv("f")
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed conduct       AVG
# 0      Joe        K  9.800000  10.0   9.900000    A+       1    Good  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000     A       0    Good  9.900000
# 3     Mary        N  7.700000   8.0   8.992857     B       0    Good  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1    Good  9.600000
# 5      Raj        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000     A       1    Good  9.366667
# 7     Mari        N  7.700000   8.0   7.100000     B       1    Good  7.600000
# 8     Jess        K  8.992857   9.1   9.900000    A+       1    Good  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000     A       0    Good  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000     A       0    Good  9.164286
# ...
