# %%
import requests
user=input("Enter your favourite city")
api_key='5cfdf46b1d7b4cd39df53623242802'
city = user
url= f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response=requests.get(url)

data=response.json()
if response.status_code==200:
  print(data)
  print("city = ",data['location']['name'])
  print("state = ",data['location']['region'])
  print("country = ",data['location']['country'])
  print("temperature in c =",data['current']['temp_c'])
  print("wind direction = ",data['current']['wind_dir'])
  print("wind speed in mph = ",data['current']['wind_mph'])
  print("humidity =",data['current']['humidity'])
  print("feels = ",data['current']['feelslike_c'])
else:
  print(data['error']['message'])
# Out:
# Enter your favourite citychintapalli
# {'location': {'name': 'Chintapalli', 'region': 'Chhattisgarh', 'country': 'India', 'lat': 18.98, 'lon': 80.67, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709109888, 'localtime': '2024-02-28 14:14'}, 'current': {'last_updated_epoch': 1709109000, 'last_updated': '2024-02-28 14:00', 'temp_c': 36.2, 'temp_f': 97.1, 'is_day': 1, 'condition': {'text': 'Partly Cloudy ', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 276, 'wind_dir': 'W', 'pressure_mb': 1009.0, 'pressure_in': 29.8, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 20, 'cloud': 30, 'feelslike_c': 34.7, 'feelslike_f': 94.4, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 9.0, 'gust_mph': 5.1, 'gust_kph': 8.3}}
# city =  Chintapalli
# state =  Chhattisgarh
# country =  India
# temperature in c = 36.2
# wind direction =  W
# wind speed in mph =  4.5
# humidity = 20
# feels =  34.7

# %%
type(data)
# Out:
# dict

# %%
print("city = ",data['location']['name'])
# Out:
# city =  Chintapalli

# %%
print("city = ",data['location']['name'])
print("state = ",data['location']['region'])
print("country = ",data['location']['country'])
print("temperature in c =",data['current']['temp_c'])
print("wind direction = ",data['current']['wind_dir'])
print("wind speed in mph = ",data['current']['wind_mph'])
print("humidity =",data['current']['humidity'])
print("feels = ",data['current']['feelslike_c'])
# Out:
# city =  Chintapalli
# state =  Chhattisgarh
# country =  India
# temperature in c = 36.2
# wind direction =  W
# wind speed in mph =  4.5
# humidity = 20
# feels =  34.7
